# %% [markdown]
# ## Brief Notes for revision

# %% [markdown]
# ## General Commands

# %%
# accessing strings
title='Mid Term Test'
title[::2]
# Out:
# 'MdTr et'

# %%
# get a string from a sentence
customer_feedback = """The product was good but could be improved. I especially appreciated the customer support and fast response times."""

# Find the first and last occurrence of the words 'good' and 'improved' in the feedback using string methods.
# Store each position in a list as a tuple (start, end) for both words and print the list.
# Find the positions of 'good'
good_start = customer_feedback.find("good")
good_end = good_start + len("good")

# Find the positions of 'improved'
improved_start = customer_feedback.find("improved")
improved_end = improved_start + len("improved")

# Store positions in a list of tuples
positions = [(good_start, good_end), (improved_start, improved_end)]
print(positions)
# Out:
# [(16, 20), (34, 42)]

# %%
# for and while loops
# %%
# Question 1 - Loops and Lists
# You are given a list of numbers representing weekly sales in units.
weekly_sales = [120, 85, 100, 90, 110, 95, 130]
average_sales = sum(weekly_sales)/len(weekly_sales)

for sale in weekly_sales:
    if sale > average_sales:
        print('Sale of', sale, 'above average sale of ', average_sales)
    elif sale < average_sales:
        print('Sale of', sale, 'below average sale of ', average_sales)

# Write a for loop that iterates through the list and prints whether each week's sales were above or below the average sales for the period.
# Calculate and print the average sales.

# NOTE -> median
# get the sorted list
sorted_list = sorted(weekly_sales.copy())
len_sorted = len(sorted_list)
median_sales = sorted_list[len_sorted//2]
print(median_sales)

print('---Median sales---', median_sales)
for sale in weekly_sales:
    if sale > average_sales:
        print('Sale of', sale, 'above median sale of ', median_sales)
    elif sale < median_sales:
        print('Sale of', sale, 'below median sale of ', median_sales)


# NOTE: get first sale thats above median
for sale in weekly_sales:
    while True:
        if sale > median_sales:
            print('First sale above median', sale)
        break
# Out:
# Sale of 120 above average sale of  104.28571428571429
# Sale of 85 below average sale of  104.28571428571429
# Sale of 100 below average sale of  104.28571428571429
# Sale of 90 below average sale of  104.28571428571429
# Sale of 110 above average sale of  104.28571428571429
# Sale of 95 below average sale of  104.28571428571429
# Sale of 130 above average sale of  104.28571428571429
# 100
# ---Median sales--- 100
# Sale of 120 above median sale of  100
# Sale of 85 below median sale of  100
# Sale of 90 below median sale of  100
# Sale of 110 above median sale of  100
# Sale of 95 below median sale of  100
# Sale of 130 above median sale of  100
# First sale above median 120
# First sale above median 110
# First sale above median 130

# %%
# operations
print('---highest sale---', max(weekly_sales))
print('---lowest sale---', min(weekly_sales))
# Out:
# ---highest sale--- 130
# ---lowest sale--- 85

# %%
# removing elements from a list
weekly_sales_copy = weekly_sales.copy()

# if sale below median, remove from list
for sale in weekly_sales_copy:
    if sale < median_sales:
        weekly_sales_copy.remove(sale)
        
print(weekly_sales_copy)

# NOTE: if using pop, you'd rather not because the index number gets adjusted with each pop
# weekly_sales_copy = weekly_sales.copy()
# for i in range(len(weekly_sales_copy)):
#     print(weekly_sales_copy[i])
#     # if weekly_sales_copy[i] < median_sales:
#       #  weekly_sales_copy.pop(i)
# Out:
# [120, 100, 110, 130]

# %%
print(weekly_sales)
# Out:
# [120, 85, 100, 90, 110, 95, 130]

# %% [markdown]
# ## Data Viz

# %% [markdown]
# 1. Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns

# %%
# # general plots
# plt.bar()
# plt.barh()
# plt.scatter()
# plt.hist()
# plt.plot()
# plt.pie

# # for sublplots
# plt.subplot()

# %%
# plot a scatterplot of random numbers
x = np.random.normal(10, 200, 50)
y = [i**2 for i in x]

# NOTE: use this instead of subplot
fig, ax = plt.subplots(2, 1, figsize=(8, 10))
ax[0].hist(x)
ax[1].scatter(x, y)
ax[0].set_ylabel('Number of observations')
ax[0].set_title('Histogram of randomly distributed numbers')

ax[1].set_ylabel('Number of observations')
ax[1].set_title('Scatterplot of observations')
plt.show()

# %%
# general pie chart
pie_data = [45, 20, 5, 30]
labels = ['Kenya', 'Uganda', 'Rwanda', 'Tanzania']

# plt.subplot(2,2,1)
plt.pie(x=pie_data, labels=labels)
plt.title('Random pie chart of former Kenyan dominance in something')
plt.show()

# repeat with bar chart
plt.subplot(2,1,1)
plt.bar(x=labels, height=sorted(pie_data, reverse=True), color = 'brown')
plt.title('Random bar chart of soon-to-be-former Kenyan dominance in something')


plt.subplot(2, 1, 2)  # second subplot (bottom)
plt.barh(labels, sorted(pie_data, reverse=True), color = 'green')
plt.show()

# %% [markdown]
# ## Data Analysis

# %%
import pandas as pd
df = pd.read_csv('Coffee_company.csv')
df.head()
# Out:
#      Segment                   Country   Product   Discount Band   Units Sold  \
# 0  Beverages  United States of America   Robusta            None      2427.75
# 1  Beverages               Switzerland   Robusta            None      1981.50
# 2     Snacks                     Japan   Robusta            None      3267.00
# 3     Snacks               Switzerland   Robusta            None      1332.00
# 4     Snacks                   Belgium   Robusta            None      3705.00
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts         Sales   \
# 0                $3.90       $26.00    $42,081.00        $-      $42,081.00
# 1                $3.90       $26.00    $34,346.00        $-      $34,346.00
# 2                $3.90       $19.50    $42,471.00        $-      $42,471.00
# 3                $3.90       $19.50    $17,316.00        $-      $17,316.00
# 4                $3.90       $19.50    $48,165.00        $-      $48,165.00
#
# ...

# %%
# clean up data
# colnames
df.columns = df.columns.str.strip()

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1575 entries, 0 to 1574
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              1575 non-null   object
#  1   Country              1575 non-null   object
#  2   Product              1575 non-null   object
#  3   Discount Band        1575 non-null   object
#  4   Units Sold           1575 non-null   float64
#  5   Manufacturing Price  1575 non-null   object
#  6   Sale Price           1575 non-null   object
#  7   Gross Sales          1575 non-null   object
#  8   Discounts            1575 non-null   object
#  9   Sales                1575 non-null   object
#  10  COGS                 1575 non-null   object
#  11  Profit               1575 non-null   object
#  12  Date                 1575 non-null   object
#  13  Month Number         1575 non-null   int64
#  14  Month Name           1575 non-null   object
# ...

# %%
# convert columns to numeric
numeric_cols = ['Manufacturing Price', 'Sale Price', 
                'Gross Sales', 'Discounts',
                'Sales', 'COGS', 'Profit']

df[numeric_cols]
# Out:
#      Manufacturing Price Sale Price      Gross Sales      Discounts  \
# 0                 $3.90     $26.00       $42,081.00           $-
# 1                 $3.90     $26.00       $34,346.00           $-
# 2                 $3.90     $19.50       $42,471.00           $-
# 3                 $3.90     $19.50       $17,316.00           $-
# 4                 $3.90     $19.50       $48,165.00           $-
# ...                  ...        ...              ...            ...
# 1570            $574.60    $663.00    $1,640,925.00    $246,138.75
# 1571            $574.60    $663.00      $361,998.00     $54,299.70
# 1572             $11.05     $15.47       $21,162.96      $3,174.44
# 1573             $22.10     $15.47       $11,184.81      $1,677.72
# 1574            $552.50     $26.52       $47,895.12      $7,184.27
#
#                 Sales             COGS        Profit
# 0         $42,081.00       $21,040.50    $16,185.00
# 1         $34,346.00       $17,173.00    $13,210.00
# ...

# %% [markdown]
# In this case, I need to remove the dollar sign, negatives

# %%
df1 = df.copy()
df1[numeric_cols]

for col in numeric_cols:
    df1[col] = df1[col].str.strip().str.replace("\$|,|-|\(|\)", '', regex=True)
    df1[col] = df1[col].replace('', float('nan'))
    df1[col] = df1[col].apply(lambda x: float(x))
    print(col, '...done')
# Out:
# Manufacturing Price ...done
# Sale Price ...done
# Gross Sales ...done
# Discounts ...done
# Sales ...done
# COGS ...done
# Profit ...done

# %%
# fix date
df1['Date'] = pd.to_datetime(df1['Date'], format='%d/%m/%Y')

# %%
# total sales
print('Total sales ->', round(df1['Sales'].sum(), 2))
print('Average sales ->', df1['Sales'].mean())

# quarterly sales
df1.set_index('Date', inplace=True)

# Calculate quarterly sales
quarterly_sales = df1['Sales'].resample('QE').sum().reset_index()
quarterly_sales.columns = ['Quarter', 'Total Sales']

# restore index
df1.reset_index(inplace=True)

print('quarterly sales ...',quarterly_sales)
# Out:
# Total sales -> 408015039.63
# Average sales -> 259057.1680190476
# quarterly sales ...       Quarter  Total Sales
# 0  2021-03-31  25339798.91
# 1  2021-06-30  29502044.05
# 2  2021-09-30  26476111.84
# 3  2021-12-31  38686468.77
# 4  2022-03-31  17737859.24
# 5  2022-06-30  20651430.79
# 6  2022-09-30  18533278.28
# 7  2022-12-31  27080528.13
# 8  2023-03-31  43077658.04
# 9  2023-06-30  50153474.72
# 10 2023-09-30  45009390.08
# 11 2023-12-31  65766996.78

# %%
# analytics
max_sales = quarterly_sales['Total Sales'].max()
print('Highest sales of', 
      max_sales,
      'in period',quarterly_sales[quarterly_sales['Total Sales']==max_sales]['Quarter'].dt.to_period('Q').astype(str))

min_sales = quarterly_sales['Total Sales'].min()
print('Lowest sales of',
      min_sales,
      'in period',quarterly_sales[quarterly_sales['Total Sales']==min_sales]['Quarter'].dt.to_period('Q').astype(str))
# Out:
# Highest sales of 65766996.78 in period 11    2023Q4
# Name: Quarter, dtype: object
# Lowest sales of 17737859.24 in period 4    2022Q1
# Name: Quarter, dtype: object

# %%
# plot
plt.bar(quarterly_sales['Quarter'].dt.to_period('Q').astype(str), quarterly_sales['Total Sales'], color='skyblue')

# Set the properties of the plot
plt.title('Quarterly Sales')
plt.xlabel('Quarter')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.tight_layout()

# show the plot (you need this for VS Code)
plt.show()

# highest sales are seen in 2023Q4, lowest in 
# average sales are $259,057.

# Adding data labels on top of the bars
bars  = plt.bar(quarterly_sales['Quarter'].dt.to_period('Q').astype(str), quarterly_sales['Total Sales'], color='skyblue')
# loop through each bar to add the label in the specified location
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), ha='center', va='bottom')
plt.show()

# %%
segment_sales = df1.groupby('Segment')['Sales'].sum().reset_index()

# sort high to low
segment_sales.sort_values('Sales', inplace=True)

# %%
# plot
plt.bar(segment_sales['Segment'], height=segment_sales['Sales'])
plt.xticks(rotation=45)
plt.title('Sales by segment')
# Out:
# Text(0.5, 1.0, 'Sales by segment')

# %% [markdown]
# # Forecasting

# %%
# Time series forecasting without a dataframe
# %%
# Question 5 - Linear Regression for Forecasting
# Using the dataset below, create a linear regression model to predict the demand for given prices.
# Predict the demand if the company sets the price at £26. Show a scatter plot of the data points and plot the regression line.
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Price (£): 15, 18, 20, 22, 25, 27, 30
# Demand (Units): 200, 180, 170, 160, 150, 140, 130
prices = np.array([15, 18, 20, 22, 25, 27, 30]).reshape(-1, 1)
demand =  np.array([200, 180, 170, 160, 150, 140, 130])

model = LinearRegression()
model.fit(prices, demand)

predicted_demand = model.predict(np.array([[26]]))

price_range = np.linspace(15, 30, 100).reshape(-1, 1)
demand_predictions = model.predict(price_range)

# Plot scatter and regression line
plt.scatter(prices, demand, color='blue', label='Actual Data')
plt.plot(price_range, demand_predictions, color='red', label='Regression Line')
plt.scatter([26], predicted_demand, color='green', marker='x', s=100, label=f'Predicted Demand ({predicted_demand[0]:.2f})')
plt.xlabel("Price (£)")
plt.ylabel("Demand (Units)")
plt.title("Price vs Demand Linear Regression")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Trying this on the dataset

# %%
df1.head()
# Out:
#         Date    Segment                   Country    Product Discount Band  \
# 0 2021-01-01  Beverages  United States of America   Robusta          None
# 1 2021-01-01  Beverages               Switzerland   Robusta          None
# 2 2021-06-01     Snacks                     Japan   Robusta          None
# 3 2021-06-01     Snacks               Switzerland   Robusta          None
# 4 2021-06-01     Snacks                   Belgium   Robusta          None
#
#    Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 0     2427.75                  3.9        26.0      42081.0        NaN
# 1     1981.50                  3.9        26.0      34346.0        NaN
# 2     3267.00                  3.9        19.5      42471.0        NaN
# 3     1332.00                  3.9        19.5      17316.0        NaN
# 4     3705.00                  3.9        19.5      48165.0        NaN
#
#      Sales     COGS   Profit  Month Number Month Name  Year
# ...

# %%
# dairy products
dairy = df1[df1['Segment'] == 'Dairy Products']
dairy.head()
# Out:
#          Date         Segment                   Country  \
# 7  2021-06-01  Dairy Products  United States of America
# 9  2021-06-01  Dairy Products               Switzerland
# 17 2021-06-01  Dairy Products  United States of America
# 19 2021-07-01  Dairy Products               Switzerland
# 27 2021-03-01  Dairy Products               Switzerland
#
#                    Product Discount Band  Units Sold  Manufacturing Price  \
# 7                  Typica          None       3777.0                  6.5
# 9                  Typica          None       2317.5                  6.5
# 17   Blue Mountain Coffee          None       3777.0                 13.0
# 19   Blue Mountain Coffee          None        550.5                 13.0
# 27                Bourbon          None       3241.5                156.0
#
#     Sale Price  Gross Sales  Discounts    Sales    COGS   Profit  \
# 7         15.6      39280.8        NaN  39280.8  9820.2  22662.0
# ...

# %%
print(df1['Product'].unique())

# selecting one type
arabica = df1[df1['Product'].str.strip()=='Arabica']
print(arabica.info())
print(arabica['Sale Price'].unique())
# Out:
# [' Robusta ' ' Typica ' ' Blue Mountain Coffee ' ' Bourbon ' ' Arabica '
#  ' Caturra ']
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 31 to 1574
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 243 non-null    datetime64[ns]
#  1   Segment              243 non-null    object
#  2   Country              243 non-null    object
#  3   Product              243 non-null    object
#  4   Discount Band        243 non-null    object
#  5   Units Sold           243 non-null    float64
#  6   Manufacturing Price  243 non-null    float64
#  7   Sale Price           243 non-null    float64
#  8   Gross Sales          243 non-null    float64
#  9   Discounts            225 non-null    float64
#  10  Sales                243 non-null    float64
#  11  COGS                 243 non-null    float64
#  12  Profit               243 non-null    float64
# ...

# %%
arabica_agg = arabica.groupby('Sale Price')['Units Sold'].sum().reset_index()

# %%
# can we do a regression of sales vs.demand
arabica_regression = LinearRegression()

# NOTE: use double brackets
arabica_regression.fit(arabica_agg[['Sale Price']], arabica_agg[['Units Sold']])
# Out:
# LinearRegression()

# %%
# create a price range for the regression
price_range = np.linspace(arabica_agg['Sale Price'].min(), 
                          arabica_agg['Sale Price'].max(), 100).reshape(-1, 1)

# predict demand over the price range
demand_predictions = arabica_regression.predict(price_range)
# Out:
# /Users/jeangithae/Documents/Term 2/programming/bemm458-mock-test-theycallmejeano/env/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Plot scatter and regression line
plt.scatter(arabica_agg[['Sale Price']], arabica_agg[['Units Sold']], color='blue', label='Actual Data')
plt.plot(price_range, demand_predictions, color='red', label='Regression Line')
plt.xlabel("Price ($)")
plt.ylabel("Demand (Units)")
plt.title("Price vs Demand Linear Regression")
plt.legend()
plt.show()

# %% [markdown]
# ## Exponential Smoothing
#
# | Method                                | Components Used         | When to Use?                  | Python Example |
# |--------------------------------------|------------------------|-------------------------------|---------------|
# | **Simple Exponential Smoothing (SES)** | Level                  | No trend or seasonality       | `fit = SimpleExpSmoothing(series).fit(smoothing_level=0.2)` |
# | **Holt’s Method (Double Smoothing)**  | Level + Trend          | Trend but no seasonality      | `fit = ExponentialSmoothing(series, trend="add").fit(smoothing_level=0.2, smoothing_slope=0.1)` |
# | **Holt-Winters (Triple Smoothing)**   | Level + Trend + Seasonality | Both trend and seasonality | `fit = ExponentialSmoothing(series, trend="add", seasonal="multiplicative", seasonal_periods=12).fit(smoothing_level=0.2, smoothing_slope=0.1, smoothing_seasonal=0.05)` |

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import matplotlib.pyplot as plt

# %%
monthly_sales = df1.groupby('Date')['Sales'].sum().reset_index()
monthly_sales.head()
# Out:
#         Date       Sales
# 0 2021-01-01  8590090.24
# 1 2021-02-01  9486790.83
# 2 2021-03-01  7262917.84
# 3 2021-04-01  9054207.63
# 4 2021-05-01  8073274.40

# %%
sns.lineplot(data=monthly_sales, x='Date', y='Sales')
# Out:
# <Axes: xlabel='Date', ylabel='Sales'>

# %%
model = ExponentialSmoothing(
    monthly_sales['Sales'],
    trend='additive',
    seasonal='multiplicative',
    seasonal_periods=12
)
fit = model.fit()
# Out:
# /Users/jeangithae/Documents/Term 2/programming/bemm458-mock-test-theycallmejeano/env/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:918: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
# forecast
# Step 3: Forecast for the next 12 months
forecast_periods = 24
forecast = fit.forecast(forecast_periods)

# Step 4: Prepare DataFrame for Forecasted Periods
last_date = monthly_sales['Date'].iloc[-1]
forecast_dates = pd.date_range(last_date + pd.offsets.MonthEnd(1), periods=forecast_periods, freq='M')
forecast_df = pd.DataFrame({'Date': forecast_dates, 'Sales': forecast})

# Step 5: Combine Actual and Forecasted Data
all_data = pd.concat([
    monthly_sales,
    forecast_df
]).reset_index(drop=True)
# Out:
# /var/folders/zd/zw7rddjs49n23lrqx15wk3t80000gn/T/ipykernel_12935/765761223.py:8: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   forecast_dates = pd.date_range(last_date + pd.offsets.MonthEnd(1), periods=forecast_periods, freq='M')

# %%
# Step 6: Plot Actual and Forecasted Sales
# Note that these are two plots plotted on the same figure
plt.figure(figsize=(14, 7))
plt.plot(monthly_sales['Date'], monthly_sales['Sales'], label='Actual Monthly Sales', marker='o', color='b')
plt.plot(forecast_df['Date'], forecast_df['Sales'], label='Forecasted Monthly Sales', marker='o', linestyle='--', color='r')
plt.axvline(x=last_date, color='gray', linestyle='--', label='Forecast Start')
plt.title('Actual and Forecasted Monthly Sales (Next 12 Months)')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.legend()
plt.grid(True)
plt.show()

# %%
## airline passengers
pas = pd.read_csv('airline_passengers.csv')
pas.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
# minor cleanup
pas.rename(columns={'#Passengers': 'Passengers'}, inplace=True)
pas['Month'] = pd.to_datetime(pas['Month'], format='%Y-%m')

# %%
# quick viz
plt.plot(pas['Month'], pas['Passengers'])

# %%
pas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    datetime64[ns]
#  1   Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
# for modeling, set month as index
pas_modeling_df = pas.copy().set_index('Month')

# %%
pas_modeling_df['Passengers']
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
#              ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: Passengers, Length: 144, dtype: int64

# %%
# clear case of trend, level, seasonality. use Holt Winters method, i,e exponential smoothing, additive
airlines_model = ExponentialSmoothing(pas_modeling_df['Passengers'], trend='add', seasonal='add', seasonal_periods=12)
model_fit = airlines_model.fit()
# Out:
# /Users/jeangithae/Documents/Term 2/programming/bemm458-mock-test-theycallmejeano/env/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
# predict for next year
pas_predictions = model_fit.forecast(24)
forecast_df = pas_predictions.reset_index().rename(columns={'index':'Month', 0:'Passengers'})

# %%
# plot
last_date = pas['Month'].max()
plt.figure(figsize=(14, 7))
plt.plot(pas['Month'], pas['Passengers'], label='Actual data', color='blue')
plt.plot(forecast_df['Month'], forecast_df['Passengers'], label='Forecasts', linestyle='--', color='green')
plt.axvline(x=last_date, color='gray', linestyle='--', label='Forecast Start')
plt.grid(True)
plt.legend()
plt.title('Airline Passengers predictions')
# Out:
# Text(0.5, 1.0, 'Airline Passengers predictions')

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomp = seasonal_decompose(pas.set_index('Month')['Passengers'], model='additive', period=12)
decomp.plot()
plt.show()

# %%
decomp = seasonal_decompose(pas.set_index('Month')['Passengers'], model='multiplicative', period=12)
decomp.plot()
plt.show()
